# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/Data-Science-ML-Capstone-Projects/master/baseball.csv")
df
# Out:
#       W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  \
# 0    95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2
# 1    83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2
# 2    81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11
# 3    76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7
# 4    74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7
# 5    93  891  5509  1480  308  17  232  570  1151   88  670  609  3.80   7
# 6    87  764  5567  1397  272  19  212  554  1227   63  698  652  4.03   3
# 7    81  713  5485  1370  246  20  217  418  1331   44  693  646  4.05   0
# 8    80  644  5485  1383  278  32  167  436  1310   87  642  604  3.74   1
# 9    78  748  5640  1495  294  33  161  478  1148   71  753  694  4.31   3
# 10   88  751  5511  1419  279  32  172  503  1233  101  733  680  4.24   5
# 11   86  729  5459  1363  278  26  230  486  1392  121  618  572  3.57   5
# 12   85  661  5417  1331  243  21  176  435  1150   52  675  630  3.94   2
# 13   76  656  5544  1379  262  22  198  478  1336   69  726  677  4.16   6
# 14   68  694  5600  1405  277  46  146  475  1119   78  729  664  4.14   5
# 15  100  647  5484  1386  288  39  137  506  1267   69  525  478  2.94   1
# 16   98  697  5631  1462  292  27  140  461  1322   98  596  532  3.21   0
# 17   97  689  5491  1341  272  30  171  567  1518   95  608  546  3.36   6
# 18   68  655  5480  1378  274  34  145  412  1299   84  737  682  4.28   1
# 19   64  640  5571  1382  257  27  167  496  1255  134  754  700  4.33   2
# 20   90  683  5527  1351  295  17  177  488  1290   51  613  557  3.43   1
# 21   83  703  5428  1363  265  13  177  539  1344   57  635  577  3.62   4
# 22   71  613  5463  1420  236  40  120  375  1150  112  678  638  4.02   0
# 23   67  573  5420  1361  251  18  100  471  1107   69  760  698  4.41   3
# 24   63  626  5529  1374  272  37  130  387  1274   88  809  749  4.69   1
# 25   92  667  5385  1346  263  26  187  563  1258   59  595  553  3.44   6
# 26   84  696  5565  1486  288  39  136  457  1159   93  627  597  3.72   7
# 27   79  720  5649  1494  289  48  154  490  1312  132  713  659  4.04   1
# 28   74  650  5457  1324  260  36  148  426  1327   82  731  655  4.09   1
# 29   68  737  5572  1479  274  49  186  388  1283   97  844  799  5.04   4
#
#     SHO  SV    E
# 0     8  56   88
# 1    12  45   86
# 2    10  38   79
# 3     9  37  101
# 4    12  35   86
# 5    10  34   88
# 6     4  48   93
# 7    10  43   77
# 8    12  60   95
# 9    10  40   97
# 10    9  45  119
# 11   13  39   85
# 12   12  46   93
# 13   12  45   94
# 14   15  28  126
# 15   15  62   96
# 16   13  54  122
# 17   21  48  111
# 18    7  40  116
# 19    8  35   90
# 20   14  50   88
# 21   13  41   90
# 22   12  35   77
# 23   10  44   90
# 24    7  35  117
# 25   21  47   75
# 26   18  41   78
# 27   12  44   86
# 28    6  41   92
# 29    4  36   95

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No Any Nuall Data is present in DataSet.

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# No any duplicate data are present in dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# All features are int type expect ERA

# %% [markdown]
# # Visualisation

# %%
count=df['W'].value_counts()

# %%
plt.figure(figsize=(10,8))
sns.barplot(count.index,count.values)
plt.title('W VS Count')
plt.ylabel('Count')
plt.xlabel('W')
# Out:
# Text(0.5, 0, 'W')

# %%
for i in df.columns:
    plt.figure()
    sns.distplot(df[i],color='green')

# %% [markdown]
# Mostof the winning score  is about 75-85.

# %%
for i in df.columns:
    plt.figure()
    sns.scatterplot(x='W',y=df[i],data=df,color='orange')

# %% [markdown]
# we find strong relation between W and RA, W and ER ,W and ERA,w and SV
#
# and patter of RA, ER and ERA with W looks same so they may be chance of multicolonearity.so lets check relation between them.

# %%
sns.lineplot(x=df['ER'],y=df['RA'],data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='ER', ylabel='RA'>

# %%
sns.lineplot(x=df['ER'],y=df['ERA'],data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='ER', ylabel='ERA'>

# %%
sns.lineplot(x=df['RA'],y=df['ERA'],data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='RA', ylabel='ERA'>

# %% [markdown]
# This chart clearly indicates that RA,ERA and ER are lineary releated to each other.

# %%
sns.lineplot(x=df['AB'],y=df['H'],data=df,color='blue')
# Out:
# <AxesSubplot:xlabel='AB', ylabel='H'>

# %% [markdown]
# # STATASTICAL ANALYSIS

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# # Correlation

# %%
corr=df.corr()
plt.figure(figsize=(15,10))
sns.heatmap(data=corr,annot=True)
plt.title('Correlation Chart')
# Out:
# Text(0.5, 1.0, 'Correlation Chart')

# %% [markdown]
# we can see that, ERA,RA and ER having highest negative relation with W and SV SHO and BB having high positive relation with W.

# %%
df.plot(kind='box',subplots=True,figsize=(15,10))
plt.show()

# %% [markdown]
# # VIF

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
def valcal():
    vif=pd.DataFrame()
    vif['vif factor']=[variance_inflation_factor(df.values,i) for i in range(df.shape[1])]
    vif['features']=df.columns
    print(vif)

# %%
valcal()
# Out:
#       vif factor features
# 0    1164.543214        W
# 1    3253.807721        R
# 2    5181.779465       AB
# 3    4817.334228        H
# 4    1157.105781       2B
# 5      32.435486       3B
# 6     309.301103       HR
# 7     302.099558       BB
# 8     400.292880       SO
# 9      28.665516       SB
# 10  18170.014649       RA
# 11  51175.790270       ER
# 12  23668.747242      ERA
# 13     10.411616       CG
# 14     33.258426      SHO
# 15    331.282416       SV
# 16     96.958680        E

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# Removing Outliers

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df))

# %%
threshold=3
print(np.where(z>3))
# Out:
# (array([5], dtype=int64), array([1], dtype=int64))

# %%
df_new=df[(z<3).all(axis=1)]

# %%
df_new.shape
# Out:
# (29, 17)

# %%
loss_of_data=(30-29)/30*100
loss_of_data
# Out:
# 3.3333333333333335

# %%
df=df_new

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %% [markdown]
# AS VIF of
# ER=51175
# ERA=23668
#
# so we will drop this columns.

# %%
df=df.drop(['ER','ERA'],axis=1)

# %% [markdown]
# Skewness Removing

# %%
df.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
s=['R','CG','SHO','SV']

for i in s:
    df[i]=np.sqrt(df[i])

# %%
df.head()
# Out:
#     W          R    AB     H   2B  3B   HR   BB    SO   SB   RA        CG  \
# 0  95  26.907248  5575  1497  300  42  139  383   973  104  641  1.414214
# 1  83  26.381812  5467  1349  277  44  156  439  1264   70  700  1.414214
# 2  81  25.865034  5439  1395  303  29  141  533  1157   86  640  3.316625
# 3  76  24.939928  5533  1381  260  27  136  404  1231   68  701  2.645751
# 4  74  26.248809  5605  1515  289  49  151  455  1259   83  803  2.645751
#
#         SHO        SV    E
# 0  2.828427  7.483315   88
# 1  3.464102  6.708204   86
# 2  3.162278  6.164414   79
# 3  3.000000  6.082763  101
# 4  3.464102  5.916080   86

# %%
x=df.drop('W',axis=1)
y=df['W']

# %% [markdown]
# # STANDARD SCALER

# %%
from sklearn.preprocessing import StandardScaler

# %%
std=StandardScaler()

# %%
X=std.fit_transform(x)

# %%
x=X

# %%
x.shape
# Out:
# (29, 14)

# %% [markdown]
# # SELECTION FOR RANDOM STATE

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,mean_absolute_error,accuracy_score,r2_score
from sklearn.model_selection import train_test_split

# %%
ln=LinearRegression()

# %%
for i in range(0,15000):
    x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=i,test_size=0.20)
    ln.fit(x_train,y_train)
    pred_train=ln.predict(x_train)
    pred_test=ln.predict(x_test)
    if round(r2_score(y_train,pred_train)*100,2)==round(r2_score(y_test,pred_test)*100,2):
        print("At Random score",i,"Model Performance is very well")
        print("Random stata is:",i)
        print("Train Score",r2_score(y_train,pred_train)*100)
        print("Test Score",r2_score(y_test,pred_test)*100)
# Out:
# At Random score 12721 Model Performance is very well
# Random stata is: 12721
# Train Score 90.4596261212344
# Test Score 90.45651956149645

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=12721,test_size=0.20)

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor
from sklearn.model_selection import GridSearchCV

# %%
svr=SVR()
svrl=SVR(kernel='linear')
svrp=SVR(kernel='poly')
dtc=DecisionTreeRegressor()
knn=KNeighborsRegressor()

# %%
def fun(f):
    f.fit(x_train,y_train)
    pred=f.predict(x_test)
    print('Taining Score:-',f.score(x_train,y_train)*100)
    print('Mean Absolute Error',mean_absolute_error(y_test,pred))
    print('Mean Squared Error',mean_squared_error(y_test,pred))
    print('Root Mean Squared Erro',np.sqrt(mean_squared_error(y_test,pred)))
    print('R2 Score',r2_score(y_test,pred)*100)

# %%
fun(ln)
# Out:
# Taining Score:- 90.4596261212344
# Mean Absolute Error 3.556053319363149
# Mean Squared Error 13.763819565752895
# Root Mean Squared Erro 3.709962205434564
# R2 Score 90.45651956149645

# %%
fun(svr)
# Out:
# Taining Score:- 25.238995687548595
# Mean Absolute Error 9.869988284482396
# Mean Squared Error 154.22224639062253
# Root Mean Squared Erro 12.418624979868847
# R2 Score -6.93376097963041

# %%
fun(svrl)
# Out:
# Taining Score:- 83.84996293903265
# Mean Absolute Error 3.5080242233497714
# Mean Squared Error 23.650166922306436
# Root Mean Squared Erro 4.863143728320852
# R2 Score 83.60157917559647

# %%
fun(svrp)
# Out:
# Taining Score:- 41.77478871031296
# Mean Absolute Error 9.817417396442822
# Mean Squared Error 150.96500889043273
# Root Mean Squared Erro 12.286781876896518
# R2 Score -4.675275810007284

# %%
fun(dtc)
# Out:
# Taining Score:- 100.0
# Mean Absolute Error 5.166666666666667
# Mean Squared Error 30.833333333333332
# Root Mean Squared Erro 5.552777082985894
# R2 Score 78.62095531587056

# %%
fun(knn)
# Out:
# Taining Score:- 56.47020947802197
# Mean Absolute Error 7.400000000000001
# Mean Squared Error 70.2666666666667
# Root Mean Squared Erro 8.382521498133285
# R2 Score 51.278890600924484

# %% [markdown]
# # Ensemble Method

# %%
from sklearn.ensemble import RandomForestRegressor,AdaBoostRegressor,GradientBoostingRegressor

# %%
rfr=RandomForestRegressor()
adr=AdaBoostRegressor()
gfr=GradientBoostingRegressor()

# %%
fun(rfr)
# Out:
# Taining Score:- 91.45801167582418
# Mean Absolute Error 6.114999999999999
# Mean Squared Error 53.248583333333336
# Root Mean Squared Erro 7.297162690617041
# R2 Score 63.078794298921416

# %%
fun(adr)
# Out:
# Taining Score:- 98.56499530991569
# Mean Absolute Error 5.314153439153441
# Mean Squared Error 40.16270103720503
# Root Mean Squared Erro 6.3374049134645825
# R2 Score 72.15221037481932

# %%
fun(gfr)
# Out:
# Taining Score:- 99.9999769128999
# Mean Absolute Error 6.19211800433817
# Mean Squared Error 57.09013283722478
# Root Mean Squared Erro 7.555801270363374
# R2 Score 60.41516213135416

# %% [markdown]
# # Regularization

# %%
from sklearn.linear_model import Lasso,Ridge,ElasticNet

# %%
ls=Lasso()
rd=Ridge()
es=ElasticNet()

# %%
fun(ls)
# Out:
# Taining Score:- 85.53217182986623
# Mean Absolute Error 3.6982176342166824
# Mean Squared Error 23.584618706488868
# Root Mean Squared Erro 4.8563997679854225
# R2 Score 83.64702863186442

# %%
fun(rd)
# Out:
# Taining Score:- 89.72789288380318
# Mean Absolute Error 3.457457271175675
# Mean Squared Error 16.196477047997952
# Root Mean Squared Erro 4.024484693472936
# R2 Score 88.76977708536351

# %%
fun(es)
# Out:
# Taining Score:- 80.02688348882165
# Mean Absolute Error 4.995010398811144
# Mean Squared Error 35.51398236258955
# Root Mean Squared Erro 5.95936090219325
# R2 Score 75.3755129997453

# %% [markdown]
# # HyperTuning For Best Score

# %% [markdown]
# LinearRegression

# %%
p1={'n_jobs':[1,2,3,4,5],'copy_X':['True','False'],'fit_intercept':['True','False'],'positive':['True','False']}

# %%
g1=GridSearchCV(ln,p1)
g1.fit(x,y)
print(g1.best_params_)
# Out:
# {'copy_X': 'True', 'fit_intercept': 'True', 'n_jobs': 1, 'positive': 'True'}

# %%
ln1=LinearRegression(copy_X=True,fit_intercept=True,n_jobs=1)

# %%
fun(ln1)
# Out:
# Taining Score:- 90.4596261212344
# Mean Absolute Error 3.556053319363149
# Mean Squared Error 13.763819565752895
# Root Mean Squared Erro 3.709962205434564
# R2 Score 90.45651956149645

# %% [markdown]
# LASSO

# %%
p2={'alpha':[10,1,0.1,0.001,0.0001,0.00001],'fit_intercept':['True','False'],'copy_X':['True','False'],'max_iter':[10,50,75,100,250,500,1000,3000,5000,10000],'selection':['cyclic','random'],'positive':['True','False']}

# %%
g2=GridSearchCV(ls,p2)
g2.fit(x,y)
print(g2.best_params_)
# Out:
# {'alpha': 0.1, 'copy_X': 'False', 'fit_intercept': 'True', 'max_iter': 10, 'positive': 'True', 'selection': 'random'}

# %%
ls1=Lasso(alpha=0.001,copy_X=False,max_iter=5,fit_intercept=True)

# %%
fun(ls1)
# Out:
# Taining Score:- 89.15676449943028
# Mean Absolute Error 3.995979637306192
# Mean Squared Error 20.444518026715688
# Root Mean Squared Erro 4.521561458911698
# R2 Score 85.82429412631424

# %% [markdown]
# RIDGE

# %%
p3={'alpha':[10,1,0.1,0.01,0.001,0.0001],'fit_intercept':['True','False'],'copy_X':['True','False'],'max_iter':[5,10,50,75,100,250,500]}

# %%
g3=GridSearchCV(rd,p3)
g3.fit(x,y)
print(g3.best_params_)
# Out:
# {'alpha': 1, 'copy_X': 'True', 'fit_intercept': 'True', 'max_iter': 5}

# %%
rd1=Ridge(alpha=1,copy_X=True,fit_intercept=True,max_iter=5)

# %%
fun(rd1)
# Out:
# Taining Score:- 89.72789288380318
# Mean Absolute Error 3.457457271175675
# Mean Squared Error 16.196477047997952
# Root Mean Squared Erro 4.024484693472936
# R2 Score 88.76977708536351

# %% [markdown]
# # Cross Validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(ls1,x,y,cv=3)
print("At value of cv=3 score is",score.mean())
# Out:
# At value of cv=3 score is 0.3713551407202891

# %%
score=cross_val_score(ln1,x,y,cv=4)
print("At value of cv=3 score is",score.mean())
# Out:
# At value of cv=3 score is 0.2621716827125781

# %%
score=cross_val_score(knn,x,y,cv=3)
print("At value of cv=3 score is",score.mean())
# Out:
# At value of cv=3 score is 0.21661012743046967

# %%
score=cross_val_score(rd,x,y,cv=3)
print("At value of cv=3 score is",score.mean())
# Out:
# At value of cv=3 score is 0.37256016899308225

# %%
score=cross_val_score(svrl,x,y,cv=3)
print("At value of cv=3 score is",score.mean())
# Out:
# At value of cv=3 score is 0.437918419851437

# %%
score=cross_val_score(rd1,x,y,cv=3)
print("At value of cv=3 score is",score.mean())
# Out:
# At value of cv=3 score is 0.37256016899308225

# %% [markdown]
# # Model Saving:

# %% [markdown]
# From the R2_Score ,RMSE and CV score we get best output in  RIDGE.

# %%
import pickle
filename='BaseBall_Prediction.pkl'
pickle.dump(rd1,open(filename,'wb'))

# %% [markdown]
# # Conclusion:-

# %%
res=pd.DataFrame()
res['Actual']=y_test
res['Predict']=rd1.predict(x_test)

print(res)

x=np.array(y_test)
y=np.array(ls1.predict(x_test))

plt.plot(x,y,'o')

m,b=np.polyfit(x,y,1)

plt.plot(x,m*x+b)
plt.xlabel('Regressor Line')
plt.title('RIDGE Regressor')
# Out:
#     Actual    Predict
# 27      79  82.939633
# 19      64  68.884755
# 17      97  90.345166
# 2       81  80.883453
# 6       87  89.227386
# 15     100  97.078412
# Text(0.5, 1.0, 'RIDGE Regressor')
